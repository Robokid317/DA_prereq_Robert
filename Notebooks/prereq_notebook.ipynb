# %% [markdown]
# Hey everyone this is Robert! I am very new to coding and this is my first time with CodeYou! Like learning a new language I am just getting my bearings

# %%
introduction = ("Hey everyone this is Robert! I am very new to coding and this is my first time with CodeYou! Like learning a new language I am just getting my bearings!")
print(introduction)
# Out:
# Hey everyone this is Robert! I am very new to coding and this is my first time with CodeYou! Like learning a new language I am just getting my bearings!
